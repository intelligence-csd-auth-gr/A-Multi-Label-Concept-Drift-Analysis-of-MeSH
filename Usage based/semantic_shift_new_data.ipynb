# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/MyDrive/AMULET/
# Out:
# /content/gdrive/MyDrive/AMULET

# %%
# %pwd
# Out:
# '/content/gdrive/My Drive/AMULET'

# %%
import numpy as np

def generate(vocab_file, vectors_file, normalization = False):

    raw_freq = {}
    with open(vocab_file, 'r') as f:
        for x in f.readlines():
            raw_freq[x.rstrip().split(' ')[0]] = x.rstrip().split(' ')[1]
    with open(vocab_file, 'r') as f:
        words = [x.rstrip().split(' ')[0] for x in f.readlines()]
    with open(vectors_file, 'r') as f:
        vectors = {}
        for line in f:
            vals = line.rstrip().split(' ')
            vectors[vals[0]] = [float(x) for x in vals[1:]]

    vocab_size = len(words)
    vocab_glove = {w: idx for idx, w in enumerate(words)}
    ivocab_glove = {idx: w for idx, w in enumerate(words)}

    vector_dim = len(vectors[ivocab_glove[0]])
    W = np.zeros((vocab_size, vector_dim))
    for word, v in vectors.items():
        if word == '<unk>':
            continue
        W[vocab_glove[word], :] = v

    # normalize each word vector to unit variance
    W_norm = np.zeros(W.shape)
    d = (np.sum(W ** 2, 1) ** (0.5))
    W_norm = (W.T / d).T

    if normalization:
      return (W_norm, vocab_glove, ivocab_glove, raw_freq)
    else:
      return (W, vocab_glove, ivocab_glove, raw_freq)

# %%
year_a = 2015
year_b = 2016
_VEC_DIM = 50
_WINDOW = 10
_NUM_ITERATIONS = 50

glove_path = '/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/'
glove_path_a = '/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/'+ str(year_a) +'/'
glove_path_b = '/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/'+ str(year_b) +'/'

print('Loading GloVe word vectors for year:', year_a)
glove_representations_a, vocab_glove_a, ivocab_glove_a, raw_freq_a = generate(glove_path_a+"vocab_"+str(year_a)+str(_VEC_DIM)+str(_NUM_ITERATIONS)+str(_WINDOW), glove_path_a+"vectors_"+str(year_a)+str(_VEC_DIM)+str(_NUM_ITERATIONS)+str(_WINDOW)+".txt", normalization = True)
print('W_glove_preview_a:\n', glove_representations_a, glove_representations_a.shape, len(vocab_glove_a), len(ivocab_glove_a))
print('Loading GloVe word vectors for year:', year_b)
glove_representations_b, vocab_glove_b, ivocab_glove_b, raw_freq_b = generate(glove_path_b+"vocab_"+str(year_b)+str(_VEC_DIM)+str(_NUM_ITERATIONS)+str(_WINDOW), glove_path_b+"vectors_"+str(year_b)+str(_VEC_DIM)+str(_NUM_ITERATIONS)+str(_WINDOW)+".txt", normalization = True)
print('W_glove_preview_b:\n', glove_representations_b, glove_representations_b.shape, len(vocab_glove_b), len(ivocab_glove_b))
# Out:
# Loading GloVe word vectors for year: 2015
# W_glove_preview_a:
#  [[-0.01442009 -0.03402605  0.05198131 ... -0.06275311 -0.15993551
#    0.22689601]
#  [ 0.00874586 -0.09918768  0.0446918  ...  0.02031538 -0.0841706
#    0.19365608]
#  [-0.13387098  0.01632587  0.07410746 ... -0.01804057 -0.08962123
#    0.09384304]
#  ...
#  [-0.0294471   0.01525655 -0.06686196 ...  0.02601947 -0.10047408
#   -0.02435168]
#  [ 0.11438165 -0.13976011 -0.0432953  ... -0.00589196 -0.13381387
#   -0.31354613]
#  [ 0.14632004  0.01801446 -0.0178317  ...  0.07368621 -0.12486345
#   -0.20712641]] (146511, 50) 146511 146511
# Loading GloVe word vectors for year: 2016
# W_glove_preview_b:
#  [[-0.00505951  0.04405434 -0.07584668 ... -0.02949477 -0.12789908
#    0.15108067]
#  [ 0.08243186 -0.00993407 -0.04499974 ... -0.06465371 -0.11312894
#    0.10820854]
#  [-0.00132215 -0.03341998 -0.0227822  ... -0.03928124 -0.07171849
#    0.0045288 ]
#  ...
#  [ 0.0869546   0.11377376 -0.1438401  ...  0.01082068 -0.34008756
#    0.27107312]
#  [ 0.17948778 -0.0158364   0.0244168  ...  0.13340807 -0.16851577
#   -0.0956866 ]
#  [ 0.01576563 -0.01042506  0.08109977 ... -0.23899111  0.09976768
#   -0.24117534]] (127747, 50) 127747 127747

# %%
def topK(label, glove_representations, vocab_glove, ivocab_glove, vocab_glove_of_the_other, k=10, count = None, min_freq = 0):#w, space, ):
  # identify the top k neighbors of a word in a space

  # compute similarity of w with all words in the vocabulary
  sim = glove_representations.dot(glove_representations[vocab_glove[label], :])

  # sort similarities by descending order
  sort_sim = (sim.argsort())[::-1]

  # choose topK
  if count:
    print('COUNT IS TRUE')
    # consider only the neighbors whose raw frequency is greater than min_freq
    best = []
    for i in sort_sim:
      if label != ivocab_glove[i] and int(count[ivocab_glove[i]]) > min_freq and ivocab_glove[i] in vocab_glove_of_the_other.keys():
        best.append(i)
        if len(best) == k:
          break
  else:
     best = sort_sim[:(k + 1)]

  return [ivocab_glove[i] for i in best if label != ivocab_glove[i]]

# %%
# !pip install tqdm

# %%
import pandas as pd
import json
from tqdm import tqdm
import csv

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2013', 'r') as f13:
    data_2013 = json.load(f13)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2014', 'r') as f14:
    data_2014 = json.load(f14)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2015', 'r') as f15:
    data_2015 = json.load(f15)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2016', 'r') as f16:
    data_2016 = json.load(f16)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2017', 'r') as f17:
    data_2017 = json.load(f17)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2018', 'r') as f18:
    data_2018 = json.load(f18)

with open('/content/gdrive/MyDrive/AMULET/glove4LVR/GloVe/glove datasets/labels_dict_2019', 'r') as f19:
    data_2019 = json.load(f19)


data_labels = list(data_2013.keys())+list(data_2014.keys())+list(data_2015.keys())+list(data_2016.keys())+list(data_2017.keys())+list(data_2018.keys())+list(data_2019.keys())
print('before', len(data_labels))
data_labels = list(set(data_labels))
print('after', len(data_labels))
print(data_labels)

data_labels_processed = []
for label in data_labels:
    data_labels_processed.append(label.replace(',','').replace(' ', '#'))
print('data_labels_processed', len(data_labels_processed))
print(data_labels_processed)

# compute nearest neighbors overlap for all the common words
nn_scores = []
common_labels = 0
for i, label in enumerate(data_labels_processed):
  # ensure the word is in both spaces
  # frequency in text shoulδ be checked here
  if label in vocab_glove_a.keys() and label in vocab_glove_b.keys() and int(raw_freq_a[label])>10 and int(raw_freq_b[label])>10:
    # identify the top-k neighbors
    common_labels += 1
    neighbors_a = topK(label, glove_representations_a, vocab_glove_a, ivocab_glove_a, vocab_glove_b, k=50, count=raw_freq_a, min_freq = 10)
    print(common_labels, '.', label, ':', 'freq --',raw_freq_a[label], 'neighbors:', neighbors_a)
    neighbors_b = topK(label, glove_representations_b, vocab_glove_b, ivocab_glove_b, vocab_glove_a, k=50, count=raw_freq_b, min_freq = 10)
    print(common_labels, '.', label, ':', 'freq --',raw_freq_b[label], 'neighbors:', neighbors_b)
    nn_scores.append((len(set(neighbors_a).intersection(set(neighbors_b))), label))
    print()
print('len of ranking', len(nn_scores))

# rank these words
nn_scores_sorted = sorted(nn_scores)
print(year_a,'-',year_b)
for cncpt in nn_scores_sorted:
  print(cncpt)


# year_labels_f1_score_diffs = {}
# f1_scores_passing_year_protocol = csv.DictReader(open("/content/gdrive/MyDrive/Colab_notebooks/AMULET/Datasets/f1_score_per_year_for_most_frequent_labels.csv"))
# for row in f1_scores_passing_year_protocol:
#     print(row)
#     # convert to dict
#     dict_row = json.loads(json.dumps(row))
#     year_labels_f1_score_diffs['2013-2014'] =
# Out:
# before 1386
# after 198
# ['base sequence', 'pilot projects', 'postoperative complications', 'stroke', 'multivariate analysis', 'oxidative stress', 'recurrence', 'computational biology', 'longitudinal studies', 'polymorphism, single nucleotide', 'dna, bacterial', 'mice, nude', 'plant extracts', 'escherichia coli', 'apoptosis', 'equipment design', 'age factors', 'genotype', 'promoter regions, genetic', 'child', 'proportional hazards models', 'molecular structure', 'tandem mass spectrometry', 'hypertension', 'health knowledge, attitudes, practice', 'biopsy', 'databases, factual', 'disease models, animal', 'bacterial proteins', 'muscle, skeletal', 'treatment outcome', 'lung', 'phenotype', 'tumor necrosis factor-alpha', 'liver neoplasms', 'body mass index', 'pain measurement', 'quality of life', 'reproducibility of results', 'prognosis', 'logistic models', 'odds ratio', 'water', 'pregnancy', 'mass spectrometry', 'cells, cultured', 'protein conformation', 'time factors', 'models, biological', 'phosphorylation', 'risk factors', 'species specificity', 'liver', 'neoplasm recurrence, local', 'kinetics', 'cell differentiation', 'nf-kappa b', 'gene expression', 'predictive value of tests', 'environmental monitoring', 'double-blind method', 'amino acid sequence', 'up-regulation', 'anti-bacterial agents', 'cell proliferation', 'roc curve', 'disease progression', 'immunohistochemistry', 'rats, sprague-dawley', 'mice, knockout', 'rna, ribosomal, 16s', 'neoplasm invasiveness', 'infant', 'nanoparticles', 'gene expression profiling', 'peptides', 'hek293 cells', 'image processing, computer-assisted', 'models, theoretical', 'binding sites', 'protein binding', 'cattle', 'real-time polymerase chain reaction', 'blood pressure', 'kidney', 'aged, 80 and over', 'child, preschool', 'reactive oxygen species', 'cytokines', 'temperature', 'dogs', 'genetic predisposition to disease', 'survival rate', 'cell line, tumor', 'case-control studies', 'sensitivity and specificity', 'japan', 'mutation', 'phylogeny', 'fibroblasts', 'signal transduction', 'feasibility studies', 'combined modality therapy', 'mice, inbred balb c', 'mice, inbred c57bl', 'rats, wistar', 'body weight', 'disease-free survival', 'swine', 'united states', 'china', 'asian continental ancestry group', 'glucose', 'oxidation-reduction', 'neoplasms', 'structure-activity relationship', 'gene expression regulation, neoplastic', 'down-regulation', 'calcium', 'sequence analysis, dna', 'antioxidants', 'comorbidity', 'risk assessment', 'linear models', 'water pollutants, chemical', 'blood glucose', 'computer simulation', 'hospitalization', 'incidence', 'hydrogen-ion concentration', 'colorectal neoplasms', 'sex factors', 'neoplasm staging', 'transcriptome', 'prevalence', 'dna', 'algorithms', 'rna, small interfering', 'severity of illness index', 'hela cells', 'models, molecular', 'depression', 'follow-up studies', 'obesity', 'breast neoplasms', 'genetic variation', 'polymerase chain reaction', 'survival analysis', 'socioeconomic factors', 'hiv infections', 'length of stay', 'antineoplastic agents', 'cell line', 'tomography, x-ray computed', 'membrane proteins', 'software', 'dose-response relationship, drug', 'rna, messenger', 'enzyme-linked immunosorbent assay', 'infant, newborn', 'administration, oral', 'magnetic resonance imaging', 'prospective studies', 'ecosystem', 'antineoplastic combined chemotherapy protocols', 'cohort studies', 'brain', 'visual acuity', 'gene expression regulation', 'diet', 'bacteria', 'kaplan-meier estimate', 'skin', 'rats', 'mitochondria', 'recombinant proteins', 'macrophages', 'stress, psychological', 'microbial sensitivity tests', 'cross-sectional studies', 'diabetes mellitus, type 2', 'cell movement', 'chromatography, high pressure liquid', 'chronic disease', 'cognition', 'prostatic neoplasms', 'cardiovascular diseases', 'imaging, three-dimensional', 'micrornas', 'inflammation', 'diagnosis, differential', 'aging', 'cell survival', 'lung neoplasms', 'registries', 'seasons', 'transcription factors', 'n ...
# data_labels_processed 198
# ['base#sequence', 'pilot#projects', 'postoperative#complications', 'stroke', 'multivariate#analysis', 'oxidative#stress', 'recurrence', 'computational#biology', 'longitudinal#studies', 'polymorphism#single#nucleotide', 'dna#bacterial', 'mice#nude', 'plant#extracts', 'escherichia#coli', 'apoptosis', 'equipment#design', 'age#factors', 'genotype', 'promoter#regions#genetic', 'child', 'proportional#hazards#models', 'molecular#structure', 'tandem#mass#spectrometry', 'hypertension', 'health#knowledge#attitudes#practice', 'biopsy', 'databases#factual', 'disease#models#animal', 'bacterial#proteins', 'muscle#skeletal', 'treatment#outcome', 'lung', 'phenotype', 'tumor#necrosis#factor-alpha', 'liver#neoplasms', 'body#mass#index', 'pain#measurement', 'quality#of#life', 'reproducibility#of#results', 'prognosis', 'logistic#models', 'odds#ratio', 'water', 'pregnancy', 'mass#spectrometry', 'cells#cultured', 'protein#conformation', 'time#factors', 'models#biological', 'phosphorylation', 'risk#factors', 'species#specificity', 'liver', 'neoplasm#recurrence#local', 'kinetics', 'cell#differentiation', 'nf-kappa#b', 'gene#expression', 'predictive#value#of#tests', 'environmental#monitoring', 'double-blind#method', 'amino#acid#sequence', 'up-regulation', 'anti-bacterial#agents', 'cell#proliferation', 'roc#curve', 'disease#progression', 'immunohistochemistry', 'rats#sprague-dawley', 'mice#knockout', 'rna#ribosomal#16s', 'neoplasm#invasiveness', 'infant', 'nanoparticles', 'gene#expression#profiling', 'peptides', 'hek293#cells', 'image#processing#computer-assisted', 'models#theoretical', 'binding#sites', 'protein#binding', 'cattle', 'real-time#polymerase#chain#reaction', 'blood#pressure', 'kidney', 'aged#80#and#over', 'child#preschool', 'reactive#oxygen#species', 'cytokines', 'temperature', 'dogs', 'genetic#predisposition#to#disease', 'survival#rate', 'cell#line#tumor', 'case-control#studies', 'sensitivity#and#specificity', 'japan', 'mutation', 'phylogeny', 'fibroblasts', 'signal#transduction', 'feasibility#studies', 'combined#modality#therapy', 'mice#inbred#balb#c', 'mice#inbred#c57bl', 'rats#wistar', 'body#weight', 'disease-free#survival', 'swine', 'united#states', 'china', 'asian#continental#ancestry#group', 'glucose', 'oxidation-reduction', 'neoplasms', 'structure-activity#relationship', 'gene#expression#regulation#neoplastic', 'down-regulation', 'calcium', 'sequence#analysis#dna', 'antioxidants', 'comorbidity', 'risk#assessment', 'linear#models', 'water#pollutants#chemical', 'blood#glucose', 'computer#simulation', 'hospitalization', 'incidence', 'hydrogen-ion#concentration', 'colorectal#neoplasms', 'sex#factors', 'neoplasm#staging', 'transcriptome', 'prevalence', 'dna', 'algorithms', 'rna#small#interfering', 'severity#of#illness#index', 'hela#cells', 'models#molecular', 'depression', 'follow-up#studies', 'obesity', 'breast#neoplasms', 'genetic#variation', 'polymerase#chain#reaction', 'survival#analysis', 'socioeconomic#factors', 'hiv#infections', 'length#of#stay', 'antineoplastic#agents', 'cell#line', 'tomography#x-ray#computed', 'membrane#proteins', 'software', 'dose-response#relationship#drug', 'rna#messenger', 'enzyme-linked#immunosorbent#assay', 'infant#newborn', 'administration#oral', 'magnetic#resonance#imaging', 'prospective#studies', 'ecosystem', 'antineoplastic#combined#chemotherapy#protocols', 'cohort#studies', 'brain', 'visual#acuity', 'gene#expression#regulation', 'diet', 'bacteria', 'kaplan-meier#estimate', 'skin', 'rats', 'mitochondria', 'recombinant#proteins', 'macrophages', 'stress#psychological', 'microbial#sensitivity#tests', 'cross-sectional#studies', 'diabetes#mellitus#type#2', 'cell#movement', 'chromatography#high#pressure#liquid', 'chronic#disease', 'cognition', 'prostatic#neoplasms', 'cardiovascular#diseases', 'imaging#three-dimensional', 'micrornas', 'inflammation', 'diagnosis#differential', 'aging', 'cell#survival', 'lung#neoplasms', 'registries', 'seasons', 'transcription#factors', 'neurons']
# COUNT IS TRUE
# 1 . postoperative#complications : freq -- 792 neighbors: ['complications', 'complication', 'complications,', 'procedure-related', '30-day', 'postoperative', 'in-hospital', 'perioperative', 'morbidity', 'pe-related', 'post-operative', 'reoperations', 'noted', 'intraoperative', 'morbidities', 'adverse', 'complication,', 'readmission', 'operative', 'treatment-related', 'postoperative#complications,', 'mortality,', 'bleeding', 'mortality', 'device-related', 'complicationsresults', 'surgery-related', 'revisions', 'readmissions', 'events', 'occurrence', 'occurred', 'morbidity,', 'outcomes', 'frequent', 'thirty-day', 'peri-operative', 'recordedresults', 'postdischarge', 'surgical', 'procedures', 'predictors', 'deaths', 'operations', 'surgeries', 'outcomes,', 'risk-adjusted', 'hospitalization', 'serious', 'events,']
# COUNT IS TRUE
# 1 . postoperative#complications : freq -- 531 neighbors: ['complications', 'complication', '30-day', 'complications,', 'perioperative', 'postoperative', 'procedure-related', 'post-operative', 'morbidity', 'operative', 'in-hospital', 'readmission', 'bleeding', 'mortality', 'recurrence', 'intraoperative', 'reoperation', 'surgeries', 'postoperative#complications,', 'readmissions', 'treatment-related', 'complication,', 'outcomes', 'occurred', 'surgery,', 'adverse', 'implant-related', 'mortality,', 'surgical', 'noted', 'outcomes,', 'procedures,', 'occurrence', 'surgery-related', 'rates,', 'rates', 'bleeding,', 'indications', 'procedures', '90-day', 'outcome', 'surgery', 'operation', 'recurrences', 'hospitalization', '1-year', 'pregnancy', 'predictors', 'morbidity,', 'comorbidities']
#
# COUNT IS TRUE
# 2 . stroke : freq -- 5825 neighbors: ['ischemic', 'ischaemic', 'infarction', 'acute', 'stroke,', 'risk', 'disease', 'incident', 'ami', 'mi', 'hemorrhagic', 'asthma', 'cardiovascular', 'exacerbations', 'pediatric', 'incidence', 'pd', 'myocardial', 'hospitalization', 'dementia', 'first-ever', 'severity', 'onset', 'stemi', 'recurrent', 'injury', 'infarction,', 'strokes', 'ed', 'mortality', 'admission', 'attack', 'tia', 'death', 'exacerbation', 'disease,', 'depression', 'strokemethods', 'heart', 'occurrence', 'chronic', 'cvd', 'prevention', 'headaches', 'hospitalized', 'neonatal', 'primary', "parkinson\\'s", 'symptomatic', 'chd']
# COUNT IS TRUE
# 2 . stroke : freq -- 4452 neighbors: ['ischemic', 'ischaemic', 'acute', 'stroke,', 'cardioembolic', 'mi', 'infarction', 'trauma', 'first-ever', 'pediatric', 'injury', 'atherothrombotic', 'ami', 'recurrent', 'dementia', 'severity', 'risk', 'aki', 'disease', 'incident', 'mortality', 'depression', 'cryptogenic', 'incidence', 'myocardial', 'cardiovascular', 'survivors', 'epilepsy', 'heart', 'onset', 'chronic', 'ais', 'kidney', 'relapse', 'hospitalization', 'asthma', 'scd', 'tia', 'esrd', 'failure', 'exacerbation', 'death', 'pd', 'stemi', 'hf', 'lymphoblastic', 'coronary', 'lacunar', 'events', 'pain']
#
# COUNT IS TRUE
# 3 . multivariate#analysis : freq -- 1464 neighbors: ['univariate', 'multivariate', 'multivariate#analysis,', 'analyses,', 'subgroup', 'multivariable', 'survival#analysis', 'analysis,', 'analyses', 'independent', 'regression', 'predictors', 'cox', 'logistic', 'univariable', 'p<0001', 'p\\\\u2009<\\\\u20090001', 'predictor', 'p=0001', 'p<00001', '0001', 'kaplan-meier', 'os', 'p<001', 'log-rank', 'statistically', 'indicated', 'independently', 'analysis', 'unadjusted', 'analysisresults', '0002', 'overall,', 'survival', 'p', 'analysesresults', '0007', 'odds#ratio', 'p=0008', 'histology', 'hazard', 'performedresults', 'bivariate', 'adjusted', 'prognostic', 'adjustment', '0004', 'recurrence', 'overall', 'revealed']
# COUNT IS TRUE
# 3 . multivariate#analysis : freq -- 1153 neighbors: ['univariate', 'multivariate', 'analyses,', 'subgroup', 'analysis,', 'multivariable', 'analyses', 'univariable', 'regression', 'survival#analysis', 'multivariate#analysis,', 'independent', 'performedresults', 'cox', 'logistic', 'indicated', 'os', 'analysisresults', 'p<00001', 'kaplan-meier', 'revealed', 'predictors', 'analysis', 'p<0001', '0002', 'unadjusted', 'mediation', '0001', 'histology', 'p\\\\u200a<\\\\u200a0001', 'statistically', 'analysesresults', 'p<001', 'hazard', 'predictor', 'confirmed', 'survival', 'overall,', 'adjusted', 'odds#ratio', 'showed', 'p\\\\u2009<\\\\u20090001', 'p\\xc2\\xa0<\\xc2\\xa005', 'p', 'independently', 'bivariate', 'p<005', 'significant', 'prognostic', '0003']
#
# COUNT IS TRUE
# 4 . oxidative#stress : freq -- 2832 neighbors: ['oxidative#stress,', 'inflammation', 'damage', 'oxidative', 'ros', 'induced', 'inflammation,', 'inflammatory', 'apoptosis', 'reactive#oxygen#species', 'induce', 'hepatic', 'antioxidant', 'metabolic', 'induces', 'inhibiting', 'mediators', 'modulating', 'metabolism', 'liver', 'cellular', 'markers', 'damage,', 'production', 'cytokine', 'attenuate', 'upregulation', 'inducing', 'altered', 'up-regulation', 'changes', 'apoptosis,', 'levels,', 'mediated', 'autophagy', 'accumulation', 'proinflammatory', 'activation', 'stress', 'alterations', 'possibly', 'responses', 'peroxidation', 'reducing', 'increases', 'lipid', 'suppressing', 'attenuated', 'immune', 'mitochondrial']
# COUNT IS TRUE
# 4 . oxidative#stress : freq -- 2475 neighbors: ['oxidative#stress,', 'inflammation', 'damage', 'oxidative', 'inflammation,', 'inflammatory', 'apoptosis', 'ros', 'reactive#oxygen#species', 'induced', 'hepatic', 'cellular', 'damage,', 'metabolic', 'metabolism', 'dysfunction', 'antioxidant', 'induce', 'attenuated', 'autophagy', 'intracellular', 'modulating', 'inhibiting', 'inducing', 'responses', 'mediators', 'induces', 'apoptosis,', 'hypoxia-induced', 'reducing', 'production', 'elevated', 'possibly', 'role', 'immune', 'protective', 'biomarkers', 'suppressing', 'response,', 'contribute', 'angiogenesis', 'altered', 'enhanced', 'cytokine', 'cytokines', 'pro-inflammatory', 'stress', 'accumulation', 'proinflammatory', 'thus,']
#
# COUNT IS TRUE
# 5 . recurrence : freq -- 4617 neighbors: ['relapse', 'recurrence,', 'recurrences', 'metastases', 'survival', 'occurrence', 'metastasis', 'distant', 'recurrent', 'os', 'overall', 'resection', 'metastatic', 'incidence', 'malignancy', 'locoregional', 'diagnosis', 'progression', 'complication', 'prognosis', 'complications', 'disease#progression', 'mortality', '5-year', 'rates', 'predicting', 'node', 'risk', 'hcc', 'predictors', 'af', 'median', 'cases', 'postoperative', 'months', 'occurred', 'pfs', 'rate', 'disease', 'surgery', 'nodal', 'tumor', 'surgical', 'tumour', 'patients', 'success', 'patients,', 'follow-up', 'survival#rate', 'colorectal']
# COUNT IS TRUE
# 5 . recurrence : freq -- 3288 neighbors: ['relapse', 'recurrence,', 'survival', 'incidence', 'rates', 'recurrent', 'occurrence', 'os', 'resection', 'progression', 'malignancy', 'rate', 'overall', 'diagnosis', 'recurrences', 'complication', 'distant', 'complications', 'mortality', 'locoregional', 'metastasis', 'occurred', 'disease#progression', 'metastatic', 'remission', 'reoperation', '5-year', 'prognosis', 'risk', 'postoperative#complications', 'surgical', 'cases', 'surgery', 'pathologic', 'success', 'delayed', 'disease', 'metastases', 'event', 'predicting', 'rfs', 'follow-up', 'rates,', 'stage', 'incident', 'failure', 'follow-up,', 'subsequent', '1-year', 'patients']
#
# COUNT IS TRUE
# 6 . longitudinal#studies : freq -- 161 neighbors: ['prospective#studies', 'warranted', 'needed"\'', 'examining', 'urgently', 'needed', 'underway', 'warranted"\'', 'gwass', 'needed,', 'required"\'', 'longer-term', 'follow-up#studies', 'confirm', 'exist', 'well-designed', 'studies"\'', 'scarce', 'few', 'exceptions,', 'investigating', 'endeavors', 'researches', 'addressed', 'connexins', 'investigations', 'structure-activity', 'necessary"\'', 'limitationsconclusion', 'this"\'', 'neededobjective', 'findings"\'', 'vois', 'epidemiological', 'clarify', 'literatures', 'exploring', 'nonetheless,', 'neededmethods', 'gaps', 'epidemiologic', 'cohort#studies', 'developing,', 'attention"\'', 'controversies', 'few,', 'studies', 'special', 'date,', 'scarce,']
# COUNT IS TRUE
# 6 . longitudinal#studies : freq -- 129 neighbors: ['prospective#studies', 'well-designed', 'warranted', 'cohort#studies', 'underway', 'follow-up#studies', 'larger-scale', 'required"\'', 'needed"\'', 'non-randomized', 'warranted"\'', 'studies"\'', 'researches', 'larger,', 'developments', 'gwass', 'rcts', 'neuroscientific', 'investigations', 'urgently', 'meta-analyses', 'needed', 'investigations"\'', 'active-controlled', 'electrophysiologic', 'neurorehabilitation', 'large-scale,', 'studiesobjective', 'needed,', 'pre-clinical', 'trials', 'deserve', 'gwas,', 'researchers', 'warrant', 'studies', 'evaluation"\'', 'today', 'studies,', 'epidemiological', 'exceptions', 'prospective', 'nonrandomized', 'projects', 'investigating', 'bioequivalence', 'preferably', 'future', 'hematemesis', 'studymaterials']
#
# COUNT IS TRUE
# 7 . plant#extracts : freq -- 80 neighbors: ['estrogenic', 'ethanolic', 'methanolic', 'extracts', 'cellulases', 'compounds', 'vocs', 'antibacterial', 'pfcs', 'composites', 'dichloromethane', 'algicidal', 'extract', 'anti-oxidative', 'gums', 'fern', 'methanol', 'hydroalcoholic', '1-8', 'lignans', 'sporting', 'oligosaccharides', 'antiproliferative', '1-9', 'flavonoids', 'wastewaters', 'glucans', 'anti-tumorigenic', 'effectsmethods', 'lipases', 'immunostimulatory', 'phenolic', 'formulations', 'hybrids', 'food-grade', 'diazo', 'aroma', 'afforded', 'herbicidal', 'alkaloids', 'tested,', 'films', 'organotin', 'physicochemical', 'sorption', 'anti-seizure', 'possessed', 'derivatives', 'cytotoxicities', 'dioxin-like']
# COUNT IS TRUE
# 7 . plant#extracts : freq -- 71 neighbors: ['mrp', 'phytochemicals', 'medicinal', 'enrichments', 'extracts', 'ca2+-cam', 'hydroalcoholic', 'pesticides', 'herbal', 'pharmaceutical', 'advantages,', 'alkaloids', 'amadori', 'disadvantages', 'anti-allergic', 'mixtures', 'terminologies', 'methanolic', 'companies', 'phytotoxic', 'sulfonamides', 'plant-derived', 'blends', 'isomeric', 'compounds', 'bivalves', 'fungicides', 'rpl', 'ethanolic', 'extract', 'vu', 'industries', 'organophosphorus', 'pbde', 'neuroactive', 'mucoadhesive', 'phenolic', 'dioxin-like', 'herb', 'bioactivities', 'anti-adipogenic', 'antioxidants', 'formulations', 'commercial', 'anti-adhesion', 'crude', 'rosemary', 'anti-diabetic', 'anthelmintic', 'drawbacks']
#
# COUNT IS TRUE
# 8 . escherichia#coli : freq -- 1550 neighbors: ['coli', 'enterohemorrhagic', 'enteroaggregative', 'etec', 'o157h7,', 'strains', 'ehec', 'bacteria', 'o157h7', 'e', 'uropathogenic', 'toxin-producing', 'stec', 'bacterium', 'enteropathogenic', 'recombinant', 'enterotoxigenic', 'yeast', 'viruses', 'aureus', 'isolate', 'o157', 'pathogens', 'bl21', 'staphylococcus', 'gram-negative', 'pathogen', 'isolates', 'bacterial', 'strains,', 's', 'gram-positive', 'leishmania', 'purified', 'bl21de3', 'virus', 'k-12', 'ca-mrsa', 'de3', 'l', 'atcc', 'escherichia#coli,', 'h5n1', 'pathogenic', 'upec', 'klebsiella', 'pneumoniae', 'o104h4', 'apec', 'st131']
# COUNT IS TRUE
# 8 . escherichia#coli : freq -- 1287 neighbors: ['coli', 'bl21de3', 'enterohemorrhagic', 'enterotoxigenic', 'isolate', 'o157h7,', 'e', 'strains', 'k12', 'bacteria', 'stec', 'uropathogenic', 'o157h7', 'recombinant', 'aureus', 'gram-negative', 'staphylococcus', 'purified', 'etec', 'bacterium', 'isolates', 'bl21', 'virulent', 'bacterial', 'atcc', 'ruminantium', 'toxin-producing', 'escherichia#coli,', 'upec', 's', 'strains,', 'viruses', 'pseudomonas', 'bieneusi', 'de3', 'yeast', 'gram-positive', 'o157', 'k-12', 'ehec', 'isolates,', 'adenovirus', 'esbl-producing', 'adeno-associated', 'mrsa', 'aeruginosa', 'antigens', 'pathogen', 'microorganisms', 'recombinant#proteins']
#
# COUNT IS TRUE
# 9 . apoptosis : freq -- 7392 neighbors: ['proliferation', 'cell#proliferation', 'apoptosis,', 'inducing', 'induced', 'autophagy', 'apoptotic', 'inhibition', 'inhibiting', 'viability', 'upregulation', 'induces', 'induce', 'cell', 'promoted', 'induction', 'suppressed', 'downregulation', 'inhibited', 'cell#survival', 'attenuated', 'suppression', 'up-regulation', 'activation', 'cells', 'suppressing', 'oxidative#stress', 'down-regulation', 'cells,', 'overexpression', 'enhanced', 'cytotoxicity', 'p53-mediated', 'migration', 'inhibits', 'triggered', 'damage', 'activation,', 'mediated', 'furthermore,', 'suppresses', 'autophagy,', 'promotes', 'moreover,', 'caspase-dependent', 'fas-mediated', 'prevented', 'expression', 'trail-mediated', 'vitro,']
# COUNT IS TRUE
# 9 . apoptosis : freq -- 5318 neighbors: ['cell#proliferation', 'proliferation', 'autophagy', 'apoptosis,', 'inducing', 'apoptotic', 'induces', 'induced', 'inhibiting', 'inhibition', 'promoted', 'downregulation', 'induction', 'inhibited', 'upregulation', 'down-regulation', 'viability', 'suppressed', 'induce', 'activation', 'angiogenesis', 'cell', 'attenuated', 'up-regulation', 'cell#survival', 'suppressing', 'inhibits', 'oxidative#stress', 'cells', 'cells,', 'triggered', 'overexpression', 'damage', 'migration', 'cell#proliferation,', 'suppression', 'prevented', 'depletion', 'enhanced', 'fas-mediated', 'blocked', 'furthermore,', 'inhibit', 'activation,', 'pathway', 'trail-induced', 'moreover,', 'promotes', 'cycle', 'mitochondria-mediated']
#
# COUNT IS TRUE
# 10 . genotype : freq -- 3421 neighbors: ['genotypes', 'allele', 'gg', 'tt', 'alleles', 'cc', 'variant', 'aa', 'c\\\\/c', 'frequencies', 'haplotype', 'genotype,', '6e', 't\\\\/t', 'variants', 'apoe', 'carriers', 'a\\\\/a', 'allelic', 'snp', 'il28b', 'carrying', 'subtype', 'polymorphism', 'homozygous', 'hcv', 'mutation', 'constellation', 'haplotypes', 'null', 'g\\\\/g', 'subgroup', 'hb', 'hp', 'idh1', 'e', 'cg', '\\xc3\\xa54', 'polymorphisms', 'frequency', 'c', 'genetic', 'l10', 'homozygote', 'ag', 'kras', 'gstm1', '1a', 'virus', 'non-carriers']
# COUNT IS TRUE
# 10 . genotype : freq -- 2408 neighbors: ['genotypes', 'gg', 'tt', 'cc', 'allele', 'val\\\\/val', 'c\\\\/c', 'alleles', 'variant', 'frequencies', 'aa', 'apoe', 'carriers', 'apoe\\xc3\\xa54', 'genotype,', 'a\\\\/a', 'carrying', 'mutation', 'v600e', 'subtype', 'hcv', 'braf', 'haplotype', 'genotypes,', 'homozygous', 'polymorphism', 'c', 'polymorphisms', 't\\\\/t', 'a\\\\/g', 'cyp2c19', 'spcas9', 'variants', '\\xc3\\xa54', 'kras', 'subgroup', 'hbv', '5-httlpr', '\\xc3\\xa52', 'idh', 'snp', 'hpv', 'gt', 'met\\\\/met', 'apoe4', 'polyposis', 'jak2v617f', 'carriers,', 'kd', 'snps']
#
# COUNT IS TRUE
# 11 . child : freq -- 2893 neighbors: ['adolescent', 'health', 'infant', 'sexual', 'youth', "children\\'s", "women\\'s", 'health,', 'childhood', 'mental', 'experiences', 'parental', "child\\'s", 'mother', 'parents', 'social', 'mothers', 'young', 'professional', 'well-being', 'welfare', 'self-reported', 'unborn', 'abuse', 'psychological', 'maternal', 'illness', 'life', 'problems', 'life,', 'adolescents', 'offspring', 'participation', 'maltreatment', 'children', 'behaviors', 'infertility', 'physical', 'psychosocial', 'perceived', 'school', 'wellbeing', 'depression', 'perceptions', 'older', "patient\\'s", 'behaviour', 'people', 'emotional', 'adult']
# COUNT IS TRUE
# 11 . child : freq -- 2389 neighbors: ['experiences', 'sexual', 'health', 'childhood', "women\\'s", 'mother', 'mental', 'adolescent', 'youth', 'abuse', "child\\'s", 'parents', "parents\\'", 'parental', 'professional', 'health,', 'maltreatment', 'maternal', 'behaviors', 'infant', 'maltreatment,', 'problems', 'school', "children\\'s", 'parent', 'personal', 'illness', 'perceptions', 'life', 'satisfaction', 'experience', 'students', 'education', 'unborn', 'perceived', 'self-reported', 'externalizing', 'social', 'offspring', 'health"\'', 'well-being', 'welfare', 'young', 'mothers', 'female', 'dental', 'psychological', 'symptoms', 'children', 'violence']
#
# COUNT IS TRUE
# 12 . proportional#hazards#models : freq -- 203 neighbors: ['cox', 'proportional', 'proportional-hazard', 'proportional-hazards', 'hazards', 'proportional#hazards#modelsresults', 'proportional#hazards#models,', 'multivariable-adjusted', "cox\\'s", 'calculate', 'joinpoint', 'poisson', 'multivariable', 'log-binomial', 'logistic#models', 'odds#ratios', 'competing-risks', 'regressions', 'covariate-adjusted', 'tobit', 'regression', 'multivariate', 'hrs', 'kaplan-meier', 'logistic', 'ordinal', 'modelresults', 'plink', 'modelled', 'unadjusted', 'hazards,', 'regression,', 'modelsresults', 'bivariable', 'qr', 'bivariate', 'searched', 'logistics', 'hazard', 'ors', 'multilevel', 'log-linear', 'multivariate#analysisresults', 'age-period-cohort', 'aors', 'separately', 'estimate', 'discrete-time', 'multivariate-adjusted', 'bioinformatically']
# COUNT IS TRUE
# 12 . proportional#hazards#models : freq -- 149 neighbors: ['proportional-hazards', 'cox', 'proportional', "cox\\'s", 'hazards', 'proportional#hazards#models,', 'a10', 'log-binomial', 'proportional#hazards#modelsresults', 'multinomial', 'quantile', 'poisson', 'multivariable-adjusted', 'logistic', 'multivariable', 'modelsresults', 'regression', 'regressions', 'regressionresults', 'regression,', 'mixed-effects', 'logistic#models', 'calculate', 'joinpoint', 'modelresults', 'multivariate-adjusted', 'multivariate', 'multilinear', 'usedresults', 'mixed-effect', 'modelingresults', 'sex-stratified', 'hazards,', 'multilevel', 'random-effects', 'hazard', 'conditional', 'unconditional', 'covariate-adjusted', 'kaplan-meier', 'fixed-effects', 'mlr', 'ordinal', 'subdistribution', 'univariate', 'estimate', 'logit', 'gee', 'plsr', 'compute']
#
# COUNT IS TRUE
# 13 . molecular#structure : freq -- 76 neighbors: ['morphological,', 'molecular#structure,', 'broadest', 'physiochemical', 'vibrational', 'stabilities', 'physicochemical', 'geometrical', 'geometry,', 'physical-chemical', 'physico-chemical', 'wavenumbers', 'photophysical', 'molecular#structures', 'rarity', 'reusability', 'phylogenetic,', 'clinicoradiological', 'rheological', 'pharmacodynamics', 'phenotypic,', 'spatio-temporal', 'characters', 're-', 'widest', 'plausibility', 'peculiarities', 'antigenicity', 'physiological,', 'landscape', 'adnexa', 'immunophenotypic', 'viewpoints', 'spectrum"\'', 'characteristics"\'', 'purities', 'norm,', 'basics', 'spectrum,', 'topological', 'temporal-spatial', 'dmpk', 'geochemical', 'vvibdv', 'thermodynamic', 'organoleptic', 'lea', 'uniqueness', 'methodology,', 'qualities']
# COUNT IS TRUE
# 13 . molecular#structure : freq -- 54 neighbors: ['biogeography', 'distinctiveness', 'specifics', 'generalizability', "parents\\'", 'neuroanatomical', 'perceptions', "method\\'s", "partners\\'", 'generalisability', 'misperceptions', 'bmiconclusions', 'understandings', 'prognosisresults', 'normative', 'fears', 'textural', 'taxonomy', 'photophysical', "relatives\\'", "midwives\\'", 'microhabitat', 'physiochemical', 'rankings', 'physics', "participants\\'", 'interestresults', 'rapidity', 'outlining', 'own', 'systematics', 'pamps', 'uniqueness', 'demography', 'qualities', 'dependencies', 'broad-scale', "professionals\\'", 'peculiarities', 'landscape', 'gender-specific', 'reptile', 'topological', 'molecular#structures', "respondents\\'", 'bioactives', 'neighbours', 'inaccuracy', 'heritability', 'suitability']
#
# COUNT IS TRUE
# 14 . hypertension : freq -- 3427 neighbors: ['diabetes', 'uncontrolled', 'hypertension,', 'pulmonary', 'mellitus', 'arterial', 'htn', 't2d', 'dyslipidemia', 'pregnancy-induced', 'blood#pressure', 'diabetes,', 'renovascular', 'gdm', 'pah', 'risk#factors', 'disease,', 'atherosclerosis', 'portal', 'obesity', 'mellitus,', 'hyperglycemia', 't2dm', 'cardiovascular', 'pe', 'embolism', 'obesity,', 'copd', 'chronic', 'atherosclerosis,', 'hypertensive', 'asthma', 'hypotension', 'hypertension"\'', 'disease', 'preeclampsia', 'cteph', 'severe', 'cvd', 'prehypertension', 'prevalence', 'obstructive', 'type#2#diabetes#mellitus', 't1d', 'incident', 'systolic', 'risk', 'resistance,', 'systemic', 'associated']
# COUNT IS TRUE
# 14 . hypertension : freq -- 2670 neighbors: ['white-coat', 'pulmonary', 'diabetes', 'renovascular', 'hypertension,', 'copd', 'uncontrolled', 'arterial', 'embolism', 'pregnancy-induced', 'asthma', 'hypertensive', 'mellitus', 'obstructive', 'blood#pressure', 'obesity,', 'iih', 'diabetes,', 'pah', 'disease,', 'salt-induced', 'exacerbation', 'systemic', 'pe', 'cteph', 'dyslipidemia', 't2dm', 'obesity', 'intracranial', 'cardiovascular', 'htn', 'disease', 'icp', 'dyslipidemia,', 't1d', 'diabetic', 'copd,', 'osa', 'cad', 'type#2#diabetes#mellitus', 'chronic', 'pressure', 'exacerbations', 'mellitus,', 'hypertension"\'', 't2d', 'severe', 'risk#factors', 'prevalence', 'hyperglycemia']
#
# COUNT IS TRUE
# 15 . biopsy : freq -- 3036 neighbors: ['biopsies', 'specimens', 'biopsy,', 'endomyocardial', 'specimen', 'cnb', 'punch', 'needle', 'excisional', 'aspiration', 'specimens,', 'slnb', 'trus-guided', 'transbronchial', 'cores', 'fna', 'sln', 'underwent', 'node', 'colonoscopy', 'histopathology', 'biopsies,', 'resection', 'cervical', 'cytology', 'diagnosis', 'examination', 'lesions', 'specimens"\'', 'mri', 'fine-needle', 'endoscopic', 'lesion', 'lymph', 'ct', 'suspected', 'ultrasound', 'prostate', 'examinations', 'trephine', 'ultrasound-guided', 'resected', 'skin', 'routine', 'duplex', 'surgical', 'histology', 'transrectal', 'scans', 'evaluation']
# COUNT IS TRUE
# 15 . biopsy : freq -- 2081 neighbors: ['biopsies', 'biopsy,', 'specimens', 'specimen', 'punch', 'trus-guided', 'resection', 'sln', 'lesions', 'specimens,', 'needle', 'cnb', 'duplex', 'histology', 'fnab', 'prostate', 'underwent', 'cytology', 'examination', 'occult', 'endomyocardial', 'fna', 'crclm', 'transbronchial', 'endoscopic', 'transrectal', 'diagnosis', 'histopathology', 'cavity', 'cervical', 'samples', 'snb', 'examinations', 'swab', 'lesion', 'node', 'lymph', 'transperineal', 'bladder', 'excisional', 'biopsies,', 'cores', 'sections', 'metastases', 'resected', 'skin', 'samples,', 'lumpectomy', 'suspected', 'mri']
#
# COUNT IS TRUE
# 16 . treatment#outcome : freq -- 205 neighbors: ['treatment#outcomes', 'prognosis"\'', 'outcome"\'', 'outcome,', 'os"\'', 'ebf', 'outcomeconclusions', 'prognosis', 'adherence', 'unfavourable', 'uneventful,', 'suboptimal', 'non-adherence', 'acceptability', 'survivalconclusions', 'outcomeresults', 'treatment#outcomes,', 'predictors', 'intention', 'post-lt', 'prognoses', 'prognosis,', 'dfs', 'prognosisconclusion', 'outcomes"\'', 'outcomesresults', 'poor', 'disease-free#survival', 'predicting', 'favourable', 'qol', 'checklist', 'unfavorable', 'outcomes', 'outcomesobjective', 'noncompliance', 'pfs', 'progression-free', 'outcomes,', 'mortalityconclusions', 'gds', 'dexrazoxane', 'prognostic', 'os', 'outcomesmethods', 'disease-specific', 'grave', 'halted', 'survivalconclusion', 'survivalresults']
# COUNT IS TRUE
# 16 . treatment#outcome : freq -- 145 neighbors: ['treatment#outcomes', 'expectations', 'survivalconclusions', 'prognosis', 'dismal', 'non-adherence', 'outcome"\'', 'outcomeconclusions', 'prognosis"\'', 'prognosis,', 'pep', 'non-response', 'postsurgical', 'disease-specific', 'outcomemethods', 'predictors,', 'outcomesmethods', 'practice,', 'mortalityconclusion', 'clinician', 'prognoses', 'predicting', 'survivalconclusion', 'sbt', 'vemurafenib', 'benefit"\'', 'non-traditional', 'outcomes"\'', 'acm', 'judgement', 'longer-term', 'anticipated', 'prolong', 'midterm', 'cisplatin-based', 'outcome,', "physicians\\'", 'survival"\'', 'suspicion', 'prognostication', 'medium-term', 'discussing', 'rfs', 'tolvaptan', 'intent', 'predicts', 'gpa', "patients\\'", 'adherence', 'predictors']
#
# COUNT IS TRUE
# 17 . lung : freq -- 11149 neighbors: ['liver', 'kidney', 'renal', 'cancer,', 'cancer', 'inflammation', 'pancreatic', 'tissue', 'fibrosis', 'colon', 'prostate', 'ovarian', 'tissues', 'gastric', 'colorectal', 'human', 'skin', 'hcc', 'carcinoma', 'interstitial', 'breast', 'non-small-cell', 'nsclc', 'injury', 'epithelial', 'pulmonary', 'tumor', 'hepatic', 'small-cell', 'glioma', 'adenocarcinoma', 'non-small', 'parenchyma', 'disease', 'hepatocellular', 'cancers', 'advanced', 'brain', 'crc', 'bladder', 'metastasis', 'a549', 'intestinal', 'diseases', 'colonic', 'tissue,', 'inflammation,', 'cell', 'metastases', 'disease,']
# COUNT IS TRUE
# 17 . lung : freq -- 8025 neighbors: ['kidney', 'liver', 'renal', 'cancer', 'cancer,', 'brain', 'interstitial', 'fibrosis', 'pancreatic', 'non-small-cell', 'prostate', 'tissue', 'bladder', 'colorectal', 'breast', 'colon', 'tissues', 'non-small', 'disease', 'nsclc', 'inflammation', 'disease,', 'human', 'skin', 'gastric', 'cancers', 'tumor', 'metastatic', 'injury', 'carcinoma', 'adenocarcinoma', 'hcc', 'chronic', 'parenchyma', 'lesions', 'acute', 'pulmonary', 'microsomes,', 'parenchymal', 'advanced', 'fibrosis,', 'metastasis', 'small-cell', 'alk-rearranged', 'injury,', 'vascular', 'a549', 'glioma', 'inflammation,', 'progression']
#
# COUNT IS TRUE
# 18 . phenotype : freq -- 3838 neighbors: ['phenotypes', 'phenotype,', 'differentiation', 'pattern', 'exhibit', 'mutant', 'alteration', 'displayed', 'phenotypic', 'proliferative', 'show', 'altered', 'cells', 'features', 'induced', 'distinct', 'profile', 'characterized', 'response', 'moreover,', 'display', 'observed', 'cells,', 'furthermore,', 'responses', 'exhibited', 'heterogeneous', 'typical', 'showed', 'markers', 'morphology', 'progression', 'similar', 'alterations', 'differentiated', 'demonstrated', 'found', 'proliferation', 'mice', 'enhanced', 'dominant', 'that', 'marked', 'wild-type', 'deletion', 'interestingly,', 'variant', 'mouse', 'signature', 'also']
# COUNT IS TRUE
# 18 . phenotype : freq -- 2892 neighbors: ['phenotypes', 'phenotype,', 'pattern', 'differentiation', 'altered', 'responses', 'immune', 'induced', 'heterogeneous', 'phenotypic', 'response', 'alterations', 'distinct', 'morphology', 'characterized', 'robust', 'cells', 'aging', 'subset', 'displayed', 'exhibit', 'profile', 'signature', 'moreover,', 'cells,', 'display', 'alteration', 'show', 'impaired', 'mutant', 'cell', 'observed', 'defective', 'responses,', 'marker', 'aggressive', 'consistent', 'similar', 'accompanied', 'furthermore,', 'behavior', 'gene#expression', 'suppression', 'tumors', 'proliferation', 'importantly,', 'upregulation', 'adaptive', 'csc', 'genetic']
#
# COUNT IS TRUE
# 19 . tumor#necrosis#factor-alpha : freq -- 80 neighbors: ['tnf-\\xc3\\xa1,', 'factor-\\xc3\\xa1', 'tnf\\xc3\\xa1', 'il-1\\xc3\\xa2,', 'tnf-\\xc3\\xa1', 'tnf\\xc3\\xa1,', 'interleukin-6', 'il-6,', 'ifn\\xc3\\xa3,', 'ifn-\\xc3\\xa3,', 'il-8,', 'interleukin-1\\xc3\\xa2', 'factor-alpha', 'tnf,', 'necrosis', 'trans-signaling', 'factor-\\xc3\\xa1,', 'il-6', 'il-10,', 'il-1\\xc3\\xa2', 'tnf-alpha', 'il-1,', '-308', 'il-1\\xc3\\xa1,', 'interferon-\\xc3\\xa3,', 'coagulative', 'avascular', 'interleukin', 'il-12,', '\\xc3\\xa1,', 'fetoprotein', 'cytokines', 'il-8', 'il-17,', 'interleukin-1', 'interleukin-1\\xc3\\xa2,', 'factor-related', 'm2-pk', 'mcp-1,', 'il-2,', 'il-22,', 'il-17a,', 'interleukin-6,', 'tnf', 'trichothecene', 'il-12p70,', '28b', 'ip-10,', 'tnf-\\xc3\\xa1-induced', 'alpha,']
# COUNT IS TRUE
# 19 . tumor#necrosis#factor-alpha : freq -- 59 neighbors: ['tnf-\\xc3\\xa1,', 'tnf-\\xc3\\xa1', 'il-1\\xc3\\xa2,', 'tnf\\xc3\\xa1', 'il-1,', 'interleukin-1\\xc3\\xa2', 'factor-\\xc3\\xa1', 'il-6,', 'ifn\\xc3\\xa3,', 'il-10,', 'ifn-\\xc3\\xa3,', 'interleukin-1beta', 'il-8,', 'tnf\\xc3\\xa1,', 'il-12,', 'interleukin-6', 'il-1\\xc3\\xa2', 'il-12p70,', 'il-17,', 'tnf-alpha,', 'il-1ra,', 'il-6', 'il-18,', 'factor-\\xc3\\xa1,', 'ifn-\\xc3\\xa1,', 'necrosis', 'interferon-\\xc3\\xa3', 'tnf-alpha', 'il-2,', 'il-15,', 'interferon-\\xc3\\xa3,', 'il-23,', 'tnf,', 'il-1\\xc3\\xa1,', 'il-4,', 'inflammasome-mediated', 'factor-alpha', 'tnf-\\xc3\\xa1-induced', 'interleukin', 'factor-related', 'tgf-\\xc3\\xa2,', 'ip-10,', 'cytokines', 'il-18', 'cox-2,', 'il-4', 'il-10', 'il6', 'no,', 'il-5,']
#
# COUNT IS TRUE
# 20 . body#mass#index : freq -- 1983 neighbors: ['bmi', 'bmi,', 'kg\\\\/m2', 'prepregnancy', 'waist', 'kg\\\\/m2,', 'body#mass#index,', 'age,', 'pre-pregnancy', 'bmiresults', 'weight,', 'overweight', 'age', 'z-score,', 'bmimethods', 'height', 'weight', 'circumference', 'height,', 'kg\\\\/m\\xc2\\xb2', 'z-score', 'circumference,', 'sex,', 'bmi>30', 'body#weight,', 'gender,', 'obesity', 'obese', 'obesity,', 'pre-gestational', 'gestational', 'mean', 'women,', 'gender', '185-249', 'diabetes,', 'men,', 'baseline', 'adiposity', 'wc,', 'men', 'overweight,', 'body', 'body#weight', 'matched', 'bmi<25', 'adjustment', 'blood#pressure,', 'diabetes', 'underweight']
# COUNT IS TRUE
# 20 . body#mass#index : freq -- 1562 neighbors: ['bmi', 'bmi,', 'kg\\\\/m2', 'pre-pregnancy', 'waist', 'age,', 'kg\\\\/m2,', 'prepregnancy', 'body#mass#index,', 'bmimethods', 'weight,', 'age', 'circumference', 'overweight', 'obesity', 'sex,', 'weight', 'bmiresults', 'wc', 'z-score', 'gender,', 'circumference,', 'wc,', 'height', 'bmi>30', '85th', 'height,', 'obese', 'obesity,', 'gestational', 'baseline', 'bmi-matched', 'mean', 'kg\\\\/m', 'wet\\\\/dry', 'blood#pressure,', 'body#weight,', 'men,', 'sd', '185', 'bmi<25', 'bmi<30', 'diabetes', 'mass,', 'younger', 'smoking,', 'gender', 'kg\\\\/m\\xc2\\xb2', 'diabetes,', 'whr']
#
# COUNT IS TRUE
# 21 . quality#of#life : freq -- 2924 neighbors: ['qol', 'hrqol', 'health-related', 'qol,', 'quality-of-life', 'hrql', 'vision-related', 'hrqolmethods', 'well-being', 'quality#of#life,', 'ohrqol', 'satisfaction', 'functioning', 'subjective', "patients\\'", 'hrqol,', 'qolmethods', 'poorer', 'worse', 'questionnaire', 'outcomes', 'psychological', 'self-reported', 'scores', 'outcome', 'psychosocial', 'poor', 'impact', 'functioning,', 'patient-reported', 'health,', 'physical', 'wellbeing', 'measures', 'improvement', 'cognition', 'assessing', 'measure', 'assessment', 'improving', 'measures,', 'questionnaire,', 'cognitive', "patient\\'s", 'scale', 'health', 'whoqol-bref', 'breast-q', 'disability', "children\\'s"]
# COUNT IS TRUE
# 21 . quality#of#life : freq -- 2433 neighbors: ['qol', 'health-related', 'hrqol', 'qol,', 'quality-of-life', 'hrqol,', 'quality#of#life,', 'hrql', 'well-being', 'ohrqol', 'functioning', 'qolmethods', 'physical', "patients\\'", 'improving', 'satisfaction', 'psychological', 'whoqol-bref', 'questionnaire', 'hrqolmethods', 'wellbeing', 'scores', 'fatigue', 'poorer', 'psychosocial', 'mental', 'self-reported', 'workloads', 'symptom', "children\\'s", 'health,', 'rhinoconjunctivitis', 'outcomes', 'symptoms', 'assessment', 'qolresults', 'worse', 'quality#of#liferesults', 'assessing', 'score', 'symptoms,', 'ohip-14', 'subjective', 'quality#of#life"\'', 'pase', 'impact', 'nihss', 'patient-reported', 'constipation', 'hr-qol']
#
# COUNT IS TRUE
# 22 . prognosis : freq -- 3338 neighbors: ['poor', 'prognosis,', 'prognostic', 'favorable', 'prognosis"\'', 'worse', 'poorer', 'survival', 'outcome,', 'predicting', 'aggressive', 'dismal', 'better', 'overall', 'unfavorable', 'outcomes', 'recurrence', 'os', 'outcome"\'', 'advanced', 'outcomes,', 'prognoses', 'favourable', 'outcome', 'clinical', 'treatment#outcome', 'predict', 'long-term', 'predicts', 'survivalconclusions', 'outcomeconclusions', 'patient', 'predictor', 'predictors', 'malignancy', 'oncologic', 'crc', 'associated', 'impact', 'benefit', 'progression', 'cancer', 'predictive', 'survival,', 'outcomes"\'', 'relevance', 'metastasis', 'diagnosis', 'metastatic', 'unfavourable']
# COUNT IS TRUE
# 22 . prognosis : freq -- 2625 neighbors: ['poor', 'worse', 'prognostic', 'prognosis,', 'dismal', 'survival', 'predicting', 'poorer', 'favorable', 'outcome,', 'os', 'outcomeconclusions', 'outcomes', 'prognosis"\'', 'outcome"\'', 'better', 'outcome', 'malignancy', 'recurrence', 'overall', 'unfavorable', 'clinical', 'long-term', 'prognosisconclusion', 'predict', 'predictive', 'predictors', 'prognoses', 'progression', 'benefit', 'predictor', 'advanced', 'treatment#outcome', 'relevance', 'favourable', 'associated', 'cancer', 'hcc', 'predicts', 'diagnosis', 'independent', 'tumors', 'aggressiveness', 'improves', 'outcomes,', 'cancer,', 'crc', 'good', 'metastatic', 'outcomes"\'']
#
# COUNT IS TRUE
# 23 . logistic#models : freq -- 37 neighbors: ['log-binomial', 'polytomous', 'gee', "cox\\'s", 'bivariable', 'proportional-hazard', 'logistical', 'unconditional', 'hazards', 'bivariate', 'multinomial', 'age-period-cohort', 'mixed-effect', 'joinpoint', 'regressions', 'probit', 'multilinear', 'univariable', 'ancova', 'multivariable-adjusted', 'competing-risks', 'logit', 'logistic', 'quantile', 'analysesconclusions', 'multivariable', 'tobit', 'parameterized', 'analysisconclusions', 'equations,', 'meta-regression', 'multivariate', 'covariate-adjusted', 'proportional-hazards', 'modelingresults', 'poisson', 'logistics', 'cox-regression', 'discrete-time', 'regression', 'proportional#hazards#models', 'ordinal', 'multilevel', 'proportional#hazards#models,', 'heritabilities', 'pdx', 'modelconclusions', 'proportional', 'fixed-effect', 'analysesresults']
# COUNT IS TRUE
# 23 . logistic#models : freq -- 28 neighbors: ['meta-regression', 'log-binomial', 'multinomial', 'proportional-hazards', 'quantile', 'probit', 'fixed-effects', 'unconditional', 'multi-factor', 'bivariable', 'regressions', 'ols', 'covariate-adjusted', 'univariate,', 'multivariate,', 'joinpoint', 'gee', 'modelingresults', "cox\\'s", 'cox-regression', 'computer#simulation', 'competing-risks', 'proportional#hazards#models', 'logistical', 'bivariate', 'multilevel', 'computer#simulations', 'multi-level', 'associationsresults', 'plsr', 'satisfactorily', 'servers', 'coregistered', 'regressionsresults', 'genorm', 'methodsmethods', 'tracings', 'stereology', 'sex-stratified', 'laplace', 'employedresults', 'appended', 'noncompartmental', 'linear#models', 'penalized', 'interchangeably', 'logistic', 'formulae', 'mixed-model', 'nanosheet']
#
# COUNT IS TRUE
# 24 . odds#ratio : freq -- 3377 neighbors: ['or,', '95%', 'ci', 'odds#ratio,', 'confidence', 'adjusted', 'interval', 'hr', 'ci,', 'aor', 'interval,', 'hazard', '95%ci', '95', 'hr,', 'rr', 'odds', '107,', 'aor,', 'p<0001', '=', 'ratio,', '113,', '124,', '119,', '117', 'p<00001', 'ratio', 'risk', '105,', 'p', '104,', '129,', '132,', 'p<001', '137,', 'or\\\\u2009=', '143,', 'p<0001,', '108,', '076,', '102,', '124', '063,', '067,', '131,', '091,', '115,', '106,', '074,']
# COUNT IS TRUE
# 24 . odds#ratio : freq -- 2524 neighbors: ['or,', 'ci', 'odds#ratio,', '95%', 'adjusted', 'confidence', 'interval', 'hr', 'ci,', 'interval,', 'aor', '95', 'rr', '95%ci', 'hazard', 'hr,', 'odds', '95\\xc2\\xa0%', '102,', 'p<0001', '128,', '=', '076,', 'p<0001,', '122,', 'p<00001', '129,', 'aor,', 'ratio', '127,', '137,', '113,', 'ratio,', '095', 'p', '109,', 'risk', '067,', '108,', 'arr', '139,', 'p<001', '118,', '144,', '062,', '171,', '073,', '066', '086,', 'p<0001conclusions']
#
# COUNT IS TRUE
# 25 . water : freq -- 9828 neighbors: ['water,', 'air', 'soil', 'reclaimed', 'sediment', 'river', 'deionized', 'groundwater', 'waters', 'potable', 'environment', 'pollution', 'supply', 'temperature', 'solutions', 'tap', 'distilled', 'irrigation', 'drinking', 'quality', 'ultrapure', 'hyacinth', 'solution', 'agricultural', 'stream', 'sources', 'bottled', 'ballast', 'food', 'industrial', 'lake', 'source', 'surface', 'aqueous', 'organic', 'sediments', 'along', 'brackish', 'where', 'contamination', 'metal', 'chemistry', 'nutrient', 'application', 'conditions', 'contaminated', 'ambient', 'stagnant', 'soils', 'availability']
# COUNT IS TRUE
# 25 . water : freq -- 9060 neighbors: ['water,', 'air', 'sediment', 'soil', 'drinking', 'tap', 'deionized', 'distilled', 'food', 'river', 'environment', 'temperature', 'groundwater', 'availability', 'quality', 'soil,', 'solution', 'amount', 'potable', 'nutrients', 'where', 'ultrapure', 'contamination', 'irrigation', 'pollution', 'along', 'quantity', 'supply', 'contaminated', 'surface', 'nutrient', 'addition', 'pond', 'aqueous', 'sediments', 'bodies"\'', 'bottled', 'systems', 'solvent', 'concentration', 'application', 'seawater', 'waters', 'conditions', 'sources', 'agricultural', 'solutions', 'organic', 'natural', 'overlying']
#
# COUNT IS TRUE
# 26 . pregnancy : freq -- 4634 neighbors: ['pregnancy,', 'maternal', 'postpartum', 'pregnancies', 'birth', 'late', 'fetal', 'gestation', 'early', 'infants', 'perinatal', 'unintended', 'women', 'trimester', 'infant', 'preterm', 'premature', 'lactation', 'during', 'termination', 'weight', 'abstinence', 'feeding', 'gdm', 'singleton', 'neonatal', 'pregnant', 'gestational', 'prenatal', 'rates', 'life', 'cessation', 'prior', 'later', 'adverse', 'offspring', 'outcomes', 'occurrence', 'subsequent', 'ectopic', 'relapse', 'risk', 'mothers', 'weeks', 'mortality', 'labor', 'smoking', 'lactation,', 'continued', 'neonates']
# COUNT IS TRUE
# 26 . pregnancy : freq -- 3660 neighbors: ['pregnancy,', 'maternal', 'postpartum', 'early', 'birth', 'infant', 'pregnancies', 'outcomes', 'late', 'during', 'perinatal', 'morbidity', 'gestation', 'complications', 'perioperative', 'fetal', 'infants', 'preterm', 'lactation', 'rates', 'subsequent', 'period', 'year', 'women', 'postoperative', 'prior', 'trimester', 'before', 'weight', 'smoking', 'term', 'gestational', 'preeclampsia', 'gdm', 'neonatal', 'following', 'prenatal', 'mortality', 'occurrence', 'history', 'relapse', 'post-operative', 'unintended', 'outcomes,', 'labor', 'first', 'successful', 'outcome', 'pregnant', 'immediate']
#
# COUNT IS TRUE
# 27 . mass#spectrometry : freq -- 2090 neighbors: ['lc-ms\\\\/ms', 'chromatography-tandem', 'chromatography\\\\/tandem', 'coupled', 'hplc-ms\\\\/ms', 'time-of-flight', 'mass#spectrometry,', 'uplc-ms\\\\/ms', 'icp-ms', 'tandem', 'gc-ms\\\\/ms', 'liquid', 'chromatography', 'lc-hrms', 'maldi-tof', 'lc-ms\\\\/ms,', 'esi-ms', 'maldi-tof\\\\/tof', 'tof-sims', 'lc-esi-ms\\\\/ms', 'ionization-tandem', 'ms\\\\/ms', 'mass#spectrometryresults', 'high-resolution', 'lc-ms', 'maldi-tof-ms', 'nanosims', 'ms', 'plasma-mass#spectrometry', 'ionization', 'hdx-ms', 'high-performance', 'chromatography-electrospray', 'chromatography-mass', 'inductively', 'hplc', 'hplc-esi-ms\\\\/ms', 'liquid-chromatography', 'quadrupole', 'lc\\\\/ms\\\\/ms', 'electrospray', 'ms-based', 'uhplc-ms\\\\/ms', 'ultra-high-performance', 'hrms', 'ultraperformance', 'maldi', 'sims', 'mass-spectrometry', 'icp-ms,']
# COUNT IS TRUE
# 27 . mass#spectrometry : freq -- 1938 neighbors: ['lc-ms\\\\/ms', 'chromatography-tandem', 'tandem', 'time-of-flight', 'hplc-ms\\\\/ms', 'chromatography\\\\/tandem', 'coupled', 'maldi-tof-ms', 'mass#spectrometry,', 'uplc-ms\\\\/ms', 'liquid', 'lc\\\\/ms\\\\/ms', 'lc-esi-ms\\\\/ms', 'lc-ms-ms', 'icp-ms', 'lc-hrms', 'gc-ms\\\\/ms', 'mass#spectrometryresults', 'lc-ms', 'high-resolution', 'esi-ms', 'uhplc-ms\\\\/ms', 'chromatography', 'ms-based', 'hplc', 'ms\\\\/ms', 'ionization-tandem', 'lc-ms\\\\/ms,', 'ionization', 'maldi-tof', 'quadrupole-time-of-flight', 'triple-quadrupole', 'chromatography\\\\/electrospray', 'spectrometric', 'chromatography-mass', 'gc-ms', 'high-performance', 'maldi-tof\\\\/tof', 'electrospray', 'mass-spectrometry', 'esi-ms\\\\/ms', 'hdx-ms', 'flight', 'tof-sims', 'hrms', 'ultra-performance', 'ms', 'hr-ms', 'chromatography-quadrupole', 'desorption\\\\/ionization']
#
# COUNT IS TRUE
# 28 . protein#conformation : freq -- 18 neighbors: ['misregulated', 'intrafractional', 'neuroadaptations', 'threaten', 'stereotype', 'caspase-2', 'life-history', 'heterogeneities', 'neurobiology', 'dictate', 'mitogenome', 'pathomechanism', 'arboviruses', 'orchestrates', 'catatonia', 'underpin', 'clinicoradiological', 'intersegmental', 'savanna', 'megakaryopoiesis', 'submarine', 'tip60', 'idiosyncratic', 'male-specific', 'reconfiguration', 'cardiorenal', 'stress-response', 'sip1', 'context-specific', 'restructuring', 'multi-faceted', 'interdependent', 'underlie', 'etiopathogenesis', 'involved"\'', 'actin-dependent', 'bsg', 'railway', 'bistability', 'commonplace', 'anonymity', 'meis1', 'basics', 'e2a', 'recombinations', 'crystallization,', 'precede', 'tinnitus-related', 'ad-related', 'attribution,']
# COUNT IS TRUE
# ...
#
# COUNT IS TRUE
# 117 . cardiovascular#diseases : freq -- 257 neighbors: ['risk#factors"\'', 'cvds', 'cvd', 'chronic#diseases', 'cardiometabolic', 'cardiovascular', 'cvd,', 'sudi', 'mania,', 'cardiovascular#diseases"\'', 'chronic#diseases,', 'risk#factors', 'risk#factors,', 'risk#factorsresults', 'nontraditional', 'aetiology', 'dyslipidemia', 'nongenetic', 'cardio-metabolic', 'cardiovascular#diseases,', 'contributing', 'incident', 'chd', 'atherosclerosis,', 'modifiable', 'non-carcinogenic', 'diseases', 'hemangiomas,', 'cardiovascular-related', 'risk,', 'hypertension', 't2dm,', 'worldwide,', 'dementia,', 'acs"\'', 'diabetes,', 'stroke-related', 'risk#factorsconclusions', 'tauopathies', 'pathophysiology', 'ihd', 'inflammation-related', 'pathologies', 'obesity,', 'disease,', 'combating', 'predisposing', 'monogenic', 'arthritis"\'', 'tumor-related']
# COUNT IS TRUE
# 117 . cardiovascular#diseases : freq -- 270 neighbors: ['cvds', 'cvd', 'cardiovascular', 'risk#factors"\'', 'cvd,', 'chronic#diseases', 'risk#factors,', 'chd', 'bottlenecks', 'cardiometabolic', 'mace,', 'cardiovascular#diseases,', 'smoking-related', 'non-fatal', 'risk#factors', 'diseases,', 'late-onset', 'all-cause', 'nonrelapse', 'pathologies,', 'arrhythmic', 'nephrolithiasis', 'incident', 'diseases', 'under-5', 'cerebrovascular', 'disease-related', 'worldwide,', 'diabetes,', 'causes,', 'disease"\'', 'mortality', "alzheimer\\'s", 'obesity', 'hypertension,', 'obesity-related', 'disease,', 'modifiable', 'non-cardiovascular', 'non-carcinogenic', 'early-onset', 'chronic#disease', 'risk,', 'waterborne', 'all-cause,', 'hcv-associated', 'stroke,', 'type#2#diabetes#mellitus', 'maces,', 'dyslipidemia']
#
# COUNT IS TRUE
# 118 . micrornas : freq -- 986 neighbors: ['mirnas', 'lncrnas', 'mirs', 'mirnas,', 'rnas', 'deregulated', 'srnas', 'non-coding', 'mirna', 'dysregulated', 'noncoding', 'differentially', 'mrnas', 'microrna', 'p53-regulated', 'lncrna', 'let-7', 'transcripts', 'roles', 'play', 'regulate', 'bart', 'herpesviruses', 'lncrnas,', 'mirs,', 'targets', 'ncrnas', 'implicated', 'numerous', 'expressed', 'circulating', 'genes', 'protein-encoding', 'involved', 'ccgs', 'regulators', 'exosomal', 'mrnas,', 'deregulation', 'identifies', 'pathogenesis-related', 'shsps', 'genes,', 'discovered', 'hox', 'ernas', 'putative', 'key', 'circrnas', 'cyanotoxins']
# COUNT IS TRUE
# 118 . micrornas : freq -- 740 neighbors: ['mirnas', 'lncrnas', 'mirnas,', 'mirs', 'rnas', 'lncrnas,', 'noncoding', 'deregulated', 'differentially', 'neuropeptides', 'lncrna', 'non-histone', 'implicated', 'mirna', 'estrogen-induced', 'regulate', 'virulence-related', 'play', 'mrnas', 'dysregulated', 'srnas', 'isgs', 'lincrnas', 'regulators', 'microrna', 'androgens', 'non-coding', 'genes', 'roles', 'involved', 'candidate', 'idps', 'tsgs', 'ncrna', 'grnas', 'deregulation', 'polyadenylated', 'circulating', 'gtpases', 'transcripts', 'nbs-lrr', 'numerous', 'targets', 'recently,', 'bmps', 'degs,', 'proteins', 'secreted', 'expressed', 'single#nucleotide#polymorphisms']
#
# COUNT IS TRUE
# 119 . inflammation : freq -- 5530 neighbors: ['inflammatory', 'inflammation,', 'oxidative#stress', 'damage', 'lung', 'induced', 'systemic', 'intestinal', 'chronic', 'fibrosis', 'injury', 'stress', 'induces', 'induce', 'role', 'pulmonary', 'hepatic', 'liver', 'diseases', 'contributes', 'neuroinflammation', 'caused', 'airway', 'oxidative#stress,', 'vascular', 'tissue', 'pathogenesis', 'colonic', 'pathological', 'immune', 'mucosal', 'exacerbated', 'skin', 'allergic', 'inflammation"\'', 'contribute', 'responses', 'hypothesized', 'acute', 'brain', 'response', 'fibrotic', 'absence', 'injury,', 'altered', 'changes', 'epithelial', 'activation', 'lps-induced', 'apoptosis']
# COUNT IS TRUE
# 119 . inflammation : freq -- 4156 neighbors: ['inflammation,', 'inflammatory', 'oxidative#stress', 'systemic', 'chronic', 'damage', 'induced', 'airway', 'intestinal', 'pulmonary', 'dysfunction', 'lung', 'induces', 'fibrosis', 'hepatic', 'oxidative#stress,', 'induce', 'immune', 'mucosal', 'role', 'vascular', 'angiogenesis', 'skin', 'neuroinflammation', 'pathogenesis', 'injury,', 'injury', 'activation', 'allergic', 'mediators', 'liver', 'abnormal', 'impaired', 'epithelial', 'caused', 'diseases', 'attenuated', 'and\\\\/or', 'contributes', 'accompanied', 'hypoxia-induced', 'kidney', 'thus,', 'diabetic', 'granulomatous', 'altered', 'acute', 'remodeling', 'involvement', 'neutrophilic']
#
# COUNT IS TRUE
# 120 . aging : freq -- 1653 neighbors: ['ageing', 'young', 'adult', 'development', 'offspring', 'affects', 'impaired', 'population', 'compromised', 'aging,', 'metabolic', 'skeletal#muscle', 'developmental', 'elderly', 'altered', 'adults', 'obese', 'individuals', 'healthy', 'cognitive', 'context', 'brain', 'ad', 'humans', 'older', 'adulthood', 'accelerated', 'function', 'early', 'throughout', 'diabetic', 'neurogenesis', 'processes', 'plasticity', 'longitudinal', 'adaptation', 'cognition', 'population,', 'during', 'children', 'contribute', 'process', 'age-related', 'metabolism', 'development,', 'however,', 'affected', 'thus,', 'phenotype', 'condition']
# COUNT IS TRUE
# 120 . aging : freq -- 1579 neighbors: ['ageing', 'development', 'aging,', 'adult', 'young', 'population', 'development,', 'affects', 'adults', 'altered', 'behaviour', 'adulthood', 'metabolic', 'processes', 'phenotype', 'behavior', 'understanding', 'adaptation', 'humans', 'impaired', 'longevity', 'older', 'context', 'elderly', 'developmental', 'process', 'accelerated', 'function', 'offspring', 'skeletal#muscle', 'changes', 'individuals', 'population,', 'tauopathy', 'during', 'cognitive', 'throughout', 'phenotypes', 'underlying', 'decline', 'cognition', 'however,', 'suggests', 'age-related', 'disease', 'growing', 'regulation', 'this', 'functions', 'obesity']
#
# COUNT IS TRUE
# 121 . cell#survival : freq -- 507 neighbors: ['cell#proliferation', 'proliferation', 'migration', 'apoptosis', 'promoting', 'cell#proliferation,', 'growth,', 'suppressing', 'inhibiting', 'proliferation,', 'cell', 'promotes', 'invasiveness', 'apoptosis,', 'migration,', 'angiogenesis', 'regulating', 'cells"\'', 'cell#proliferation"\'', 'inducing', 'tumorigenesis', 'promoted', 'cell#survival,', 'invasion', 'cells,', 'signaling', 'autophagy', 'viability', 'trail-mediated', 'apoptosis"\'', 'signaling,', 'hsc', 'cell#differentiation,', 'differentiation,', 'modulating', 'promote', 'cells', 'signalling', 'killing', 'fas-mediated', 'hepatocyte', 'suppresses', 'angiogenesis,', 'induction', 'a549', 'vitro,', 'cell#differentiation', 'akt', 'enhancing', 'activation,']
# COUNT IS TRUE
# 121 . cell#survival : freq -- 402 neighbors: ['cell#proliferation', 'proliferation', 'cell#proliferation,', 'autophagy', 'apoptosis', 'proliferation,', 'migration', 'angiogenesis', 'invasion', 'migration,', 'differentiation,', 'promoted', 'apoptosis,', 'promoting', 'cell#survival,', 'viability', 'regulating', 'senescence', 'promotes', 'differentiation', 'clonogenic', 'growth,', 'glycolysis', 'mitochondria-mediated', 'vsmc', 'suppressing', 'pathway', 'autophagy,', 'inhibiting', 'induction', 'apoptosis"\'', 'hsc', 'invasiveness', 'integrin-dependent', 'osteoblast', 'fas-mediated', 'tumorigenesis', 'necroptotic', 'cardiomyocyte', 'inducing', 'cell', 'apoptotic', 'self-renewal', 'wnt\\\\/\\xc3\\xa2-catenin', 'chondrocyte', 'p53-dependent', 'modulating', 'adipogenesis', 'vitro,', 'neuronal']
#
# COUNT IS TRUE
# 122 . registries : freq -- 306 neighbors: ['registers', 'danish', 'registries,', 'oncomine', 'database', "institute\\'s", 'registry', 'national', 'swedish', 'population-based', 'tcga', 'database,', 'nationwide', 'cancer', 'taiwan', 'registers,', '2006-2010', 'registryresults', "taiwan\\'s", 'register', 'netherlands', 'atlas', 'registry,', 'datasets', 'databases', 'crc', 'manitoba', 'institute', 'seer-medicare', 'society"\'', 'consortium', 'observatory', 'survivors,', 'cell#linesmethods', 'fund', 'seer', 'french', 'bcsc', 'surveillance', 'cell#linesmaterials', 'uk', 'queried', 'k-space', 'survivors"\'', 'administrative', 'colorectal', 'projects', 'register,', 'project', 'ncdb']
# COUNT IS TRUE
# 122 . registries : freq -- 223 neighbors: ['registry', 'danish', 'database', 'registers,', 'national', 'registers', 'claims', 'registries,', 'oncomine', 'hapmap', 'taiwan', 'database,', "taiwan\\'s", 'administrative', 'sets"\'', 'databases', 'tcga', 'swedish', 'register', 'nationwide', 'institute', 'insurance', '2003-2012', 'record"\'', 'databases,', 'statewide', 'population-based', 'databasemethods', 'nhird', 'kid', '2003-2006', 'vqi', 'retrieved', 'registryresults', 'certificate', 'register,', 'ncdb', 'nci', 'registry,', 'medicare', 'survivorsmethods', 'centers', 'microarray', 'nhsn', 'uk', 'medicaid', 'rna-seq', 'crcmethods', 'queried', '2009-2011']
#
# COUNT IS TRUE
# 123 . seasons : freq -- 392 neighbors: ['winter', 'season', 'summer', 'seasons,', 'spring', 'rainy', 'spawning', '2013-2014', '2011\\\\/2012', '2011-2012', 'season,', 'autumn', '2012-2013', '2010-2011', 'periods,', 'seasonal', 'periods', 'spring,', 'non-breeding', '2000-2013', 'monsoon', 'winter,', 'epidemics', '2008-2013', 'summer,', 'autumn,', '2010-2013', '2006-2011', 'ethnicities', '2010-2012', '2011-2013', 'wet', 'ride', 'cruise', 'temperatures', '2007-2011', 'fastest', '2008-2009', '2004-2006', 'divergence', 'locations,', 'period', 'season"\'', 'slaughtered', 'larvae', '2001-2010', 'cultivars', 'bird', 'batches', '2005-2010']
# COUNT IS TRUE
# 123 . seasons : freq -- 393 neighbors: ['seasons,', 'season', 'season,', 'rainy', 'winter', 'spring', 'periods,', 'summer', 'seasonal', 'wet', '2013-14', 'autumn', 'periods', 'dry', 'spawning', 'generations', '2012-2014', '2013-2014', 'sympatric', 'habitats', 'fall', 'atlantic', 'biomes', 'post-monsoon', 'summer,', '2010-2011', 'scenarios', 'routes', '2012-13', 'periodresults', 'simulated', 'epochs', 'successive', 'breeding', '2010-2014', 'sexes,', 'pigs', 'sampled', 'occurring', '2011-2012', 'period', 'bivalves', 'fattening', '2006-2012', '2007-2013', '2010-2013', '1990', 'biotypes', 'species', 'period,']
#
# COUNT IS TRUE
# 124 . transcription#factors : freq -- 917 neighbors: ['tfs', 'bhlh', 'transcription#factors,', 'regulators', 'bzip', 'ap-1', 'transcription', 'coactivators', 'wrky', 'mrnas', 'chemosensory', 'roles', 'key', 'downstream', 'transcriptional', 'promoters', 'genes', 'eukaryotic', 'regulatory', 'genes,', 'effectors', 'pasteurellaceae', 'tfs,', 'hox', 'regulate', 't-box', 'encode', 'transcripts', 'binding#sites', 'oct4', 'interacting', 'regulates', 'regulated', 'differentially', 'basic', 'regulating', 'modules', 'repressors', 'proteins,', 'socs', 'duplicated', 'pluripotency', 'proteases', 'proteins', 'family', 'pathways', 'foxc2', 'involved', 'repressor', 'protein-coding']
# COUNT IS TRUE
# 124 . transcription#factors : freq -- 815 neighbors: ['tfs', 'regulators', 'transcription#factors,', 'transcription', 'transcriptional', 'promoters', 'regulate', 'genes', 'effectors', 'enhancers', 'regulatory', 'myb', 'proteins,', 'regulated', 'machinery', 'functions', 'putative', 'dysregulated', 'downstream', 'bhlh', 'e2f', 'roles', 'conserved', 'differentially', 'proteins', 'key', 'encode', 'housekeeping', 'pluripotency', 'pathways', 'mads-box', 'c-myc', 'repressors', 'involved', 'lineage-specific', 'regulates', 'activating', 'mrnas', 'members', 'regulating', 'binding#sites', 'family', 'regulation', 'transcripts', 'encoding', 'virulence-related', 'motifs', 'family,', 'expressed', 'stat']
#
# COUNT IS TRUE
# 125 . neurons : freq -- 5920 neighbors: ['neurons,', 'pyramidal', 'dopaminergic', 'sensory', 'da', 'projecting', 'excitability', 'hippocampal', 'astrocytes', 'neuronal', 'cortical', 'neuron', 'striatal', 'immature', 'cholinergic', 'drg', 'gabaergic', 'midbrain', 'cortex', 'cells', 'rfrp-3', 'astrocytes,', 'mature', 'circuits', 'neurons"\'', 'kisspeptin', 'microglia', 'hippocampus', 'histaminergic', 'axons', 'synapses', 'inputs', 'dopamine', 'cultured', 'hscs', 'interneurons', 'ca1', 'projection', 'osteoblasts', 'slices', 'dissociated', 'innervation', 'adipocytes', 'dorsal', 'depleted', 'postmitotic', 'motor', 'retina', 'specifically,', 't-cells']
# COUNT IS TRUE
# 125 . neurons : freq -- 4299 neighbors: ['neurons,', 'cortical', 'drg', 'astrocytes', 'axons', 'dopaminergic', 'pyramidal', 'microglia', 'hippocampal', 'neuron', 'immature', 'sensory', 'excitability', 'striatal', 'osteoblasts', 'ca1', 'sgns', 'projection', 'cortex', 'da', 'cholinergic', 'neuronal', 'mature', 'hippocampus', 'dorsal', 'circuits', 'agrp', 'motor', 'retina', 'glutamatergic', 'activation', 'dc', 'cardiomyocytes', 'cells', 'progenitors', 'rat', 'cultured', 'synapses', 'gabaergic', 'excitatory', 'serotonergic', 'inputs', 'osteoclasts', 'dcs', 'neural', 'auditory', 'interneurons', 'v1', 'sertoli', 'kndy']
#
# len of ranking 125
# 2015 - 2016
# (0, 'cell#movement')
# (1, 'oxidation-reduction')
# (1, 'protein#conformation')
# (2, 'hiv#infections')
# (5, 'protein#binding')
# (6, 'environmental#monitoring')
# (6, 'recombinant#proteins')
# (8, 'chronic#disease')
# (8, 'molecular#structure')
# (8, 'socioeconomic#factors')
# (9, 'case-control#studies')
# (9, 'computer#simulation')
# (10, 'plant#extracts')
# (12, 'follow-up#studies')
# (13, 'cross-sectional#studies')
# (13, 'structure-activity#relationship')
# (16, 'ecosystem')
# (16, 'swine')
# (17, 'amino#acid#sequence')
# (17, 'antioxidants')
# (17, 'membrane#proteins')
# (17, 'treatment#outcome')
# (19, 'longitudinal#studies')
# (19, 'seasons')
# (20, 'cardiovascular#diseases')
# (20, 'cell#differentiation')
# (20, 'hek293#cells')
# (21, 'logistic#models')
# (22, 'risk#assessment')
# (23, 'phylogeny')
# (24, 'enzyme-linked#immunosorbent#assay')
# (25, 'cattle')
# (25, 'comorbidity')
# (25, 'registries')
# (26, 'cognition')
# (26, 'hela#cells')
# (26, 'infant')
# (26, 'visual#acuity')
# (27, 'binding#sites')
# (27, 'cohort#studies')
# (27, 'linear#models')
# (27, 'neoplasms')
# (27, 'roc#curve')
# (28, 'disease#progression')
# (28, 'dogs')
# (28, 'fibroblasts')
# (28, 'genetic#variation')
# (28, 'phosphorylation')
# (29, 'body#weight')
# (29, 'cell#line')
# (29, 'genotype')
# (29, 'micrornas')
# (29, 'mitochondria')
# (29, 'phenotype')
# (29, 'proportional#hazards#models')
# (29, 'transcription#factors')
# (30, 'japan')
# (30, 'survival#analysis')
# (31, 'calcium')
# (31, 'cell#survival')
# (31, 'kinetics')
# (31, 'stroke')
# (31, 'up-regulation')
# (32, 'algorithms')
# (32, 'blood#glucose')
# (32, 'diet')
# (32, 'magnetic#resonance#imaging')
# (32, 'prospective#studies')
# (32, 'transcriptome')
# (32, 'tumor#necrosis#factor-alpha')
# (33, 'bacteria')
# (33, 'kidney')
# (33, 'macrophages')
# (33, 'neurons')
# (33, 'postoperative#complications')
# (33, 'pregnancy')
# (33, 'reactive#oxygen#species')
# (34, 'aging')
# (34, 'dna')
# (34, 'down-regulation')
# (34, 'inflammation')
# (34, 'liver')
# (34, 'obesity')
# (34, 'odds#ratio')
# (34, 'quality#of#life')
# (34, 'sensitivity#and#specificity')
# (34, 'skin')
# (34, 'united#states')
# (35, 'blood#pressure')
# (35, 'brain')
# (35, 'length#of#stay')
# (35, 'nanoparticles')
# (35, 'polymerase#chain#reaction')
# (35, 'software')
# (36, 'child')
# (36, 'depression')
# (36, 'disease-free#survival')
# (36, 'escherichia#coli')
# (36, 'hospitalization')
# (36, 'oxidative#stress')
# (36, 'peptides')
# (36, 'rats')
# (36, 'recurrence')
# (37, 'biopsy')
# (37, 'china')
# (37, 'glucose')
# (37, 'hypertension')
# (37, 'immunohistochemistry')
# (37, 'signal#transduction')
# (37, 'water')
# (38, 'body#mass#index')
# (38, 'mass#spectrometry')
# (38, 'prevalence')
# (39, 'cytokines')
# (39, 'lung')
# (39, 'risk#factors')
# (39, 'temperature')
# (40, 'mutation')
# (40, 'survival#rate')
# (41, 'apoptosis')
# (42, 'gene#expression')
# (42, 'multivariate#analysis')
# (42, 'prognosis')
# (43, 'cell#proliferation')
# (43, 'incidence')
